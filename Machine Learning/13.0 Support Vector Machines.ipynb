# %% [markdown]
# # __Support Vector Machines__

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df = pd.read_csv('breast_cancer.csv')
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  outcome
# 0          0.4601                  0.11890        1
# 1          0.2750                  0.08902        1
# 2          0.3613                  0.08758        1
# 3          0.6638                  0.17300        1
# 4          0.2364                  0.07678        1
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
X = df.iloc[:,:-1]
y = df.outcome

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=47)

# %%
X_train.shape
# Out:
# (455, 30)

# %%
X_test.shape
# Out:
# (114, 30)

# %%
from sklearn.metrics import accuracy_score, classification_report

# C parameter
# gamma value

model = SVC(
    kernel='linear',
    C=4,
    random_state=225,
    gamma=0.5
)

model.fit(X_train, y_train)

y_predict_test = model.predict(X_test)
y_predict_train = model.predict(X_train)

print('train: ', accuracy_score(y_train, y_predict_train))
print('test: ', accuracy_score(y_test, y_predict_test))
print(classification_report(y_test, y_predict_test))
# Out:
# train:  0.9714285714285714
# test:  0.9473684210526315
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96        70
#            1       0.90      0.98      0.93        44
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.95       114
# weighted avg       0.95      0.95      0.95       114

# %% [markdown]
# # __HyperParameter Tuning__

# %% [markdown]
# ## __GridSearchCV__

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'kernel': ['linear', 'rbf', 'poly'],
    'C': [0.1,0.5,1.0,2.0,5.0,10.0,25.0,50.0,10.0],
    'gamma': [0.01,0.05,0.1,0.25,0.5,1.0,5.0,10.0]
}

# %%
clf =  GridSearchCV(SVC(), param_grid=parameters,  verbose=3)

clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV 1/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   1.5s
# [CV 4/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   2.0s
# [CV 5/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   1.4s
# [CV 1/5] END ...............C=0.1, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.1, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.1, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.1, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.1, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.05, kernel=poly; total time=   0.2s
# [CV 2/5] END .................C=0.1, gamma=0.05, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=0.05, kernel=poly; total time=   1.6s
# [CV 4/5] END .................C=0.1, gamma=0.05, kernel=poly; total time=   2.8s
# [CV 5/5] END .................C=0.1, gamma=0.05, kernel=poly; total time=   1.3s
# [CV 1/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   0.2s
# [CV 2/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   1.5s
# [CV 4/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   2.7s
# [CV 5/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   1.3s
# [CV 1/5] END ...............C=0.1, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.1, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.1, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.1, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.1, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.25, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=0.1, gamma=0.25, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=0.25, kernel=poly; total time=   1.1s
# [CV 4/5] END .................C=0.1, gamma=0.25, kernel=poly; total time=   2.2s
# [CV 5/5] END .................C=0.1, gamma=0.25, kernel=poly; total time=   0.8s
# [CV 1/5] END ................C=0.1, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.5, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=0.1, gamma=0.5, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.5, kernel=poly; total time=   1.1s
# [CV 4/5] END ..................C=0.1, gamma=0.5, kernel=poly; total time=   2.3s
# [CV 5/5] END ..................C=0.1, gamma=0.5, kernel=poly; total time=   0.8s
# [CV 1/5] END ................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.1, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.1, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.1, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.1, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.1, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=1.0, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=0.1, gamma=1.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=1.0, kernel=poly; total time=   1.1s
# [CV 4/5] END ..................C=0.1, gamma=1.0, kernel=poly; total time=   2.2s
# [CV 5/5] END ..................C=0.1, gamma=1.0, kernel=poly; total time=   0.8s
# [CV 1/5] END ................C=0.1, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.1, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.1, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.1, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.1, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.1, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=5.0, kernel=poly; total time=   0.4s
# [CV 2/5] END ..................C=0.1, gamma=5.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=5.0, kernel=poly; total time=   1.9s
# [CV 4/5] END ..................C=0.1, gamma=5.0, kernel=poly; total time=   3.2s
# [CV 5/5] END ..................C=0.1, gamma=5.0, kernel=poly; total time=   1.6s
# [CV 1/5] END ...............C=0.1, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.1, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.1, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.1, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.1, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=10.0, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=0.1, gamma=10.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=10.0, kernel=poly; total time=   1.9s
# [CV 4/5] END .................C=0.1, gamma=10.0, kernel=poly; total time=   3.3s
# [CV 5/5] END .................C=0.1, gamma=10.0, kernel=poly; total time=   1.7s
# [CV 1/5] END ...............C=0.5, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.5, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.5, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.5, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.5, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.5, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.5, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.5, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.5, gamma=0.01, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=0.5, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.5, gamma=0.01, kernel=poly; total time=   1.8s
# [CV 4/5] END .................C=0.5, gamma=0.01, kernel=poly; total time=   2.2s
# [CV 5/5] END .................C=0.5, gamma=0.01, kernel=poly; total time=   1.5s
# [CV 1/5] END ...............C=0.5, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.5, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.5, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.5, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.5, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.5, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.5, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.5, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.5, gamma=0.05, kernel=poly; total time=   0.2s
# [CV 2/5] END .................C=0.5, gamma=0.05, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.5, gamma=0.05, kernel=poly; total time=   1.8s
# [CV 4/5] END .................C=0.5, gamma=0.05, kernel=poly; total time=   3.1s
# [CV 5/5] END .................C=0.5, gamma=0.05, kernel=poly; total time=   1.5s
# [CV 1/5] END ................C=0.5, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.5, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.5, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.5, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.5, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.5, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=0.1, kernel=poly; total time=   0.2s
# [CV 2/5] END ..................C=0.5, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=0.1, kernel=poly; total time=   1.8s
# [CV 4/5] END ..................C=0.5, gamma=0.1, kernel=poly; total time=   3.1s
# [CV 5/5] END ..................C=0.5, gamma=0.1, kernel=poly; total time=   1.5s
# [CV 1/5] END ...............C=0.5, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.5, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.5, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.5, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.5, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.5, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.5, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.5, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.5, gamma=0.25, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=0.5, gamma=0.25, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.5, gamma=0.25, kernel=poly; total time=   1.2s
# [CV 4/5] END .................C=0.5, gamma=0.25, kernel=poly; total time=   2.5s
# [CV 5/5] END .................C=0.5, gamma=0.25, kernel=poly; total time=   0.9s
# [CV 1/5] END ................C=0.5, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.5, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.5, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.5, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.5, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.5, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=0.5, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=0.5, gamma=0.5, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=0.5, kernel=poly; total time=   1.3s
# [CV 4/5] END ..................C=0.5, gamma=0.5, kernel=poly; total time=   2.5s
# [CV 5/5] END ..................C=0.5, gamma=0.5, kernel=poly; total time=   0.9s
# [CV 1/5] END ................C=0.5, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.5, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.5, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.5, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.5, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.5, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=1.0, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=0.5, gamma=1.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=1.0, kernel=poly; total time=   1.3s
# [CV 4/5] END ..................C=0.5, gamma=1.0, kernel=poly; total time=   2.5s
# [CV 5/5] END ..................C=0.5, gamma=1.0, kernel=poly; total time=   0.9s
# [CV 1/5] END ................C=0.5, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=0.5, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.5, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=0.5, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.5, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.5, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=5.0, kernel=poly; total time=   0.5s
# [CV 2/5] END ..................C=0.5, gamma=5.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=5.0, kernel=poly; total time=   2.1s
# [CV 4/5] END ..................C=0.5, gamma=5.0, kernel=poly; total time=   3.3s
# [CV 5/5] END ..................C=0.5, gamma=5.0, kernel=poly; total time=   2.1s
# [CV 1/5] END ...............C=0.5, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.5, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.5, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.5, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.5, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.5, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=0.5, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.5, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=0.5, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.5, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.5, gamma=10.0, kernel=poly; total time=   0.5s
# [CV 2/5] END .................C=0.5, gamma=10.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=0.5, gamma=10.0, kernel=poly; total time=   2.3s
# [CV 4/5] END .................C=0.5, gamma=10.0, kernel=poly; total time=   3.4s
# [CV 5/5] END .................C=0.5, gamma=10.0, kernel=poly; total time=   1.8s
# [CV 1/5] END ...............C=1.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=1.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=1.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=1.0, gamma=0.01, kernel=linear; total time=   0.7s
# [CV 5/5] END ...............C=1.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=1.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=1.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=1.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=1.0, gamma=0.01, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=1.0, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=1.0, gamma=0.01, kernel=poly; total time=   1.9s
# [CV 4/5] END .................C=1.0, gamma=0.01, kernel=poly; total time=   2.3s
# [CV 5/5] END .................C=1.0, gamma=0.01, kernel=poly; total time=   1.6s
# [CV 1/5] END ...............C=1.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=1.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=1.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=1.0, gamma=0.05, kernel=linear; total time=   0.7s
# [CV 5/5] END ...............C=1.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=1.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=1.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=1.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=1.0, gamma=0.05, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=1.0, gamma=0.05, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=1.0, gamma=0.05, kernel=poly; total time=   2.1s
# [CV 4/5] END .................C=1.0, gamma=0.05, kernel=poly; total time=   3.8s
# [CV 5/5] END .................C=1.0, gamma=0.05, kernel=poly; total time=   1.6s
# [CV 1/5] END ................C=1.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=1.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=1.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=1.0, gamma=0.1, kernel=linear; total time=   0.7s
# [CV 5/5] END ................C=1.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=1.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=1.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=1.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=1.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=1.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=0.1, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=1.0, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=0.1, kernel=poly; total time=   2.2s
# [CV 4/5] END ..................C=1.0, gamma=0.1, kernel=poly; total time=   4.0s
# [CV 5/5] END ..................C=1.0, gamma=0.1, kernel=poly; total time=   2.0s
# [CV 1/5] END ...............C=1.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=1.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=1.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=1.0, gamma=0.25, kernel=linear; total time=   0.8s
# [CV 5/5] END ...............C=1.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=1.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=1.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=1.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=1.0, gamma=0.25, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=1.0, gamma=0.25, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=1.0, gamma=0.25, kernel=poly; total time=   1.6s
# [CV 4/5] END .................C=1.0, gamma=0.25, kernel=poly; total time=   3.1s
# [CV 5/5] END .................C=1.0, gamma=0.25, kernel=poly; total time=   1.1s
# [CV 1/5] END ................C=1.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=1.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=1.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=1.0, gamma=0.5, kernel=linear; total time=   0.8s
# [CV 5/5] END ................C=1.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=1.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=1.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=1.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=1.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=1.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=0.5, kernel=poly; total time=   0.5s
# [CV 2/5] END ..................C=1.0, gamma=0.5, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=0.5, kernel=poly; total time=   1.7s
# [CV 4/5] END ..................C=1.0, gamma=0.5, kernel=poly; total time=   3.0s
# [CV 5/5] END ..................C=1.0, gamma=0.5, kernel=poly; total time=   1.1s
# [CV 1/5] END ................C=1.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=1.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=1.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=1.0, gamma=1.0, kernel=linear; total time=   0.7s
# [CV 5/5] END ................C=1.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=1.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=1.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=1.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=1.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=1.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=1.0, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=1.0, gamma=1.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=1.0, kernel=poly; total time=   1.3s
# [CV 4/5] END ..................C=1.0, gamma=1.0, kernel=poly; total time=   2.8s
# [CV 5/5] END ..................C=1.0, gamma=1.0, kernel=poly; total time=   1.0s
# [CV 1/5] END ................C=1.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=1.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=1.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=1.0, gamma=5.0, kernel=linear; total time=   0.7s
# [CV 5/5] END ................C=1.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=1.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=1.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=1.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=1.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=1.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=5.0, kernel=poly; total time=   0.5s
# [CV 2/5] END ..................C=1.0, gamma=5.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=5.0, kernel=poly; total time=   2.4s
# [CV 4/5] END ..................C=1.0, gamma=5.0, kernel=poly; total time=   3.5s
# [CV 5/5] END ..................C=1.0, gamma=5.0, kernel=poly; total time=   1.9s
# [CV 1/5] END ...............C=1.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=1.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=1.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=1.0, gamma=10.0, kernel=linear; total time=   0.7s
# [CV 5/5] END ...............C=1.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=1.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=1.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=1.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=1.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=1.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=1.0, gamma=10.0, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=1.0, gamma=10.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=1.0, gamma=10.0, kernel=poly; total time=   2.1s
# [CV 4/5] END .................C=1.0, gamma=10.0, kernel=poly; total time=   3.7s
# [CV 5/5] END .................C=1.0, gamma=10.0, kernel=poly; total time=   1.9s
# [CV 1/5] END ...............C=2.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=2.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=2.0, gamma=0.01, kernel=linear; total time=   0.3s
# [CV 4/5] END ...............C=2.0, gamma=0.01, kernel=linear; total time=   0.5s
# [CV 5/5] END ...............C=2.0, gamma=0.01, kernel=linear; total time=   0.2s
# [CV 1/5] END ..................C=2.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=2.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=2.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=2.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=2.0, gamma=0.01, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=2.0, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=2.0, gamma=0.01, kernel=poly; total time=   1.9s
# [CV 4/5] END .................C=2.0, gamma=0.01, kernel=poly; total time=   2.4s
# [CV 5/5] END .................C=2.0, gamma=0.01, kernel=poly; total time=   1.8s
# [CV 1/5] END ...............C=2.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=2.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=2.0, gamma=0.05, kernel=linear; total time=   0.4s
# [CV 4/5] END ...............C=2.0, gamma=0.05, kernel=linear; total time=   0.5s
# [CV 5/5] END ...............C=2.0, gamma=0.05, kernel=linear; total time=   0.3s
# [CV 1/5] END ..................C=2.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=2.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=2.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=2.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=2.0, gamma=0.05, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=2.0, gamma=0.05, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=2.0, gamma=0.05, kernel=poly; total time=   2.1s
# [CV 4/5] END .................C=2.0, gamma=0.05, kernel=poly; total time=   3.7s
# [CV 5/5] END .................C=2.0, gamma=0.05, kernel=poly; total time=   1.7s
# [CV 1/5] END ................C=2.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=2.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=2.0, gamma=0.1, kernel=linear; total time=   0.3s
# [CV 4/5] END ................C=2.0, gamma=0.1, kernel=linear; total time=   0.5s
# [CV 5/5] END ................C=2.0, gamma=0.1, kernel=linear; total time=   0.2s
# [CV 1/5] END ...................C=2.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=2.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=2.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=2.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=2.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=2.0, gamma=0.1, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=2.0, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=0.1, kernel=poly; total time=   1.9s
# [CV 4/5] END ..................C=2.0, gamma=0.1, kernel=poly; total time=   3.3s
# [CV 5/5] END ..................C=2.0, gamma=0.1, kernel=poly; total time=   1.5s
# [CV 1/5] END ...............C=2.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=2.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=2.0, gamma=0.25, kernel=linear; total time=   0.3s
# [CV 4/5] END ...............C=2.0, gamma=0.25, kernel=linear; total time=   0.5s
# [CV 5/5] END ...............C=2.0, gamma=0.25, kernel=linear; total time=   0.2s
# [CV 1/5] END ..................C=2.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=2.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=2.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=2.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=2.0, gamma=0.25, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=2.0, gamma=0.25, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=2.0, gamma=0.25, kernel=poly; total time=   1.5s
# [CV 4/5] END .................C=2.0, gamma=0.25, kernel=poly; total time=   2.6s
# [CV 5/5] END .................C=2.0, gamma=0.25, kernel=poly; total time=   1.0s
# [CV 1/5] END ................C=2.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=2.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=2.0, gamma=0.5, kernel=linear; total time=   0.3s
# [CV 4/5] END ................C=2.0, gamma=0.5, kernel=linear; total time=   0.5s
# [CV 5/5] END ................C=2.0, gamma=0.5, kernel=linear; total time=   0.3s
# [CV 1/5] END ...................C=2.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=2.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=2.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=2.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=2.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=2.0, gamma=0.5, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=2.0, gamma=0.5, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=0.5, kernel=poly; total time=   1.4s
# [CV 4/5] END ..................C=2.0, gamma=0.5, kernel=poly; total time=   2.6s
# [CV 5/5] END ..................C=2.0, gamma=0.5, kernel=poly; total time=   1.0s
# [CV 1/5] END ................C=2.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=2.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=2.0, gamma=1.0, kernel=linear; total time=   0.3s
# [CV 4/5] END ................C=2.0, gamma=1.0, kernel=linear; total time=   0.4s
# [CV 5/5] END ................C=2.0, gamma=1.0, kernel=linear; total time=   0.2s
# [CV 1/5] END ...................C=2.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=2.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=2.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=2.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=2.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=2.0, gamma=1.0, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=2.0, gamma=1.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=1.0, kernel=poly; total time=   1.3s
# [CV 4/5] END ..................C=2.0, gamma=1.0, kernel=poly; total time=   2.6s
# [CV 5/5] END ..................C=2.0, gamma=1.0, kernel=poly; total time=   1.0s
# [CV 1/5] END ................C=2.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=2.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=2.0, gamma=5.0, kernel=linear; total time=   0.3s
# [CV 4/5] END ................C=2.0, gamma=5.0, kernel=linear; total time=   0.5s
# [CV 5/5] END ................C=2.0, gamma=5.0, kernel=linear; total time=   0.3s
# [CV 1/5] END ...................C=2.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=2.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=2.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=2.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=2.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=2.0, gamma=5.0, kernel=poly; total time=   0.5s
# [CV 2/5] END ..................C=2.0, gamma=5.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=5.0, kernel=poly; total time=   2.2s
# [CV 4/5] END ..................C=2.0, gamma=5.0, kernel=poly; total time=   3.4s
# [CV 5/5] END ..................C=2.0, gamma=5.0, kernel=poly; total time=   1.7s
# [CV 1/5] END ...............C=2.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=2.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=2.0, gamma=10.0, kernel=linear; total time=   0.3s
# [CV 4/5] END ...............C=2.0, gamma=10.0, kernel=linear; total time=   0.4s
# [CV 5/5] END ...............C=2.0, gamma=10.0, kernel=linear; total time=   0.2s
# [CV 1/5] END ..................C=2.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=2.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=2.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=2.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=2.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=2.0, gamma=10.0, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=2.0, gamma=10.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=2.0, gamma=10.0, kernel=poly; total time=   2.0s
# [CV 4/5] END .................C=2.0, gamma=10.0, kernel=poly; total time=   3.3s
# [CV 5/5] END .................C=2.0, gamma=10.0, kernel=poly; total time=   1.9s
# [CV 1/5] END ...............C=5.0, gamma=0.01, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=5.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=5.0, gamma=0.01, kernel=linear; total time=   0.2s
# [CV 4/5] END ...............C=5.0, gamma=0.01, kernel=linear; total time=   0.6s
# [CV 5/5] END ...............C=5.0, gamma=0.01, kernel=linear; total time=   0.6s
# [CV 1/5] END ..................C=5.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=5.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=5.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=5.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=5.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=5.0, gamma=0.01, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=5.0, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=5.0, gamma=0.01, kernel=poly; total time=   1.9s
# [CV 4/5] END .................C=5.0, gamma=0.01, kernel=poly; total time=   2.5s
# [CV 5/5] END .................C=5.0, gamma=0.01, kernel=poly; total time=   1.7s
# [CV 1/5] END ...............C=5.0, gamma=0.05, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=5.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=5.0, gamma=0.05, kernel=linear; total time=   0.2s
# [CV 4/5] END ...............C=5.0, gamma=0.05, kernel=linear; total time=   0.5s
# [CV 5/5] END ...............C=5.0, gamma=0.05, kernel=linear; total time=   0.6s
# [CV 1/5] END ..................C=5.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=5.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=5.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=5.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=5.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=5.0, gamma=0.05, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=5.0, gamma=0.05, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=5.0, gamma=0.05, kernel=poly; total time=   1.8s
# [CV 4/5] END .................C=5.0, gamma=0.05, kernel=poly; total time=   3.3s
# [CV 5/5] END .................C=5.0, gamma=0.05, kernel=poly; total time=   1.5s
# [CV 1/5] END ................C=5.0, gamma=0.1, kernel=linear; total time=   0.1s
# [CV 2/5] END ................C=5.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=5.0, gamma=0.1, kernel=linear; total time=   0.2s
# [CV 4/5] END ................C=5.0, gamma=0.1, kernel=linear; total time=   0.6s
# [CV 5/5] END ................C=5.0, gamma=0.1, kernel=linear; total time=   0.6s
# [CV 1/5] END ...................C=5.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=5.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=5.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=5.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=5.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=5.0, gamma=0.1, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=5.0, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=5.0, gamma=0.1, kernel=poly; total time=   2.1s
# [CV 4/5] END ..................C=5.0, gamma=0.1, kernel=poly; total time=   3.4s
# [CV 5/5] END ..................C=5.0, gamma=0.1, kernel=poly; total time=   1.7s
# [CV 1/5] END ...............C=5.0, gamma=0.25, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=5.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=5.0, gamma=0.25, kernel=linear; total time=   0.2s
# [CV 4/5] END ...............C=5.0, gamma=0.25, kernel=linear; total time=   0.5s
# [CV 5/5] END ...............C=5.0, gamma=0.25, kernel=linear; total time=   0.6s
# [CV 1/5] END ..................C=5.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=5.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=5.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=5.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=5.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=5.0, gamma=0.25, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=5.0, gamma=0.25, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=5.0, gamma=0.25, kernel=poly; total time=   1.5s
# [CV 4/5] END .................C=5.0, gamma=0.25, kernel=poly; total time=   2.5s
# [CV 5/5] END .................C=5.0, gamma=0.25, kernel=poly; total time=   1.0s
# [CV 1/5] END ................C=5.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=5.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=5.0, gamma=0.5, kernel=linear; total time=   0.2s
# [CV 4/5] END ................C=5.0, gamma=0.5, kernel=linear; total time=   0.6s
# [CV 5/5] END ................C=5.0, gamma=0.5, kernel=linear; total time=   0.6s
# [CV 1/5] END ...................C=5.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=5.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=5.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=5.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=5.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=5.0, gamma=0.5, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=5.0, gamma=0.5, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=5.0, gamma=0.5, kernel=poly; total time=   1.3s
# [CV 4/5] END ..................C=5.0, gamma=0.5, kernel=poly; total time=   2.5s
# [CV 5/5] END ..................C=5.0, gamma=0.5, kernel=poly; total time=   1.0s
# [CV 1/5] END ................C=5.0, gamma=1.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ................C=5.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=5.0, gamma=1.0, kernel=linear; total time=   0.2s
# [CV 4/5] END ................C=5.0, gamma=1.0, kernel=linear; total time=   0.6s
# [CV 5/5] END ................C=5.0, gamma=1.0, kernel=linear; total time=   0.6s
# [CV 1/5] END ...................C=5.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=5.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=5.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=5.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=5.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=5.0, gamma=1.0, kernel=poly; total time=   0.3s
# [CV 2/5] END ..................C=5.0, gamma=1.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=5.0, gamma=1.0, kernel=poly; total time=   1.4s
# [CV 4/5] END ..................C=5.0, gamma=1.0, kernel=poly; total time=   2.6s
# [CV 5/5] END ..................C=5.0, gamma=1.0, kernel=poly; total time=   0.9s
# [CV 1/5] END ................C=5.0, gamma=5.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ................C=5.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=5.0, gamma=5.0, kernel=linear; total time=   0.2s
# [CV 4/5] END ................C=5.0, gamma=5.0, kernel=linear; total time=   0.5s
# [CV 5/5] END ................C=5.0, gamma=5.0, kernel=linear; total time=   0.6s
# [CV 1/5] END ...................C=5.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=5.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=5.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=5.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=5.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=5.0, gamma=5.0, kernel=poly; total time=   0.5s
# [CV 2/5] END ..................C=5.0, gamma=5.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=5.0, gamma=5.0, kernel=poly; total time=   2.1s
# [CV 4/5] END ..................C=5.0, gamma=5.0, kernel=poly; total time=   3.3s
# [CV 5/5] END ..................C=5.0, gamma=5.0, kernel=poly; total time=   1.8s
# [CV 1/5] END ...............C=5.0, gamma=10.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=5.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=5.0, gamma=10.0, kernel=linear; total time=   0.2s
# [CV 4/5] END ...............C=5.0, gamma=10.0, kernel=linear; total time=   0.6s
# [CV 5/5] END ...............C=5.0, gamma=10.0, kernel=linear; total time=   0.8s
# [CV 1/5] END ..................C=5.0, gamma=10.0, kernel=rbf; total time=   0.0s
# ...
# [CV 2/5] END ..............C=50.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=50.0, gamma=0.25, kernel=linear; total time=   0.5s
# [CV 4/5] END ..............C=50.0, gamma=0.25, kernel=linear; total time=   2.1s
# [CV 5/5] END ..............C=50.0, gamma=0.25, kernel=linear; total time=   0.9s
# [CV 1/5] END .................C=50.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=50.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=50.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=50.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=50.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=50.0, gamma=0.25, kernel=poly; total time=   0.3s
# [CV 2/5] END ................C=50.0, gamma=0.25, kernel=poly; total time=   0.0s
# [CV 3/5] END ................C=50.0, gamma=0.25, kernel=poly; total time=   1.3s
# [CV 4/5] END ................C=50.0, gamma=0.25, kernel=poly; total time=   2.8s
# [CV 5/5] END ................C=50.0, gamma=0.25, kernel=poly; total time=   1.1s
# [CV 1/5] END ...............C=50.0, gamma=0.5, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=50.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=50.0, gamma=0.5, kernel=linear; total time=   0.6s
# [CV 4/5] END ...............C=50.0, gamma=0.5, kernel=linear; total time=   2.0s
# [CV 5/5] END ...............C=50.0, gamma=0.5, kernel=linear; total time=   1.0s
# [CV 1/5] END ..................C=50.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=50.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=50.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=50.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=50.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=50.0, gamma=0.5, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=50.0, gamma=0.5, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=50.0, gamma=0.5, kernel=poly; total time=   1.4s
# [CV 4/5] END .................C=50.0, gamma=0.5, kernel=poly; total time=   2.6s
# [CV 5/5] END .................C=50.0, gamma=0.5, kernel=poly; total time=   1.0s
# [CV 1/5] END ...............C=50.0, gamma=1.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=50.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=50.0, gamma=1.0, kernel=linear; total time=   0.5s
# [CV 4/5] END ...............C=50.0, gamma=1.0, kernel=linear; total time=   1.8s
# [CV 5/5] END ...............C=50.0, gamma=1.0, kernel=linear; total time=   0.9s
# [CV 1/5] END ..................C=50.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=50.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=50.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=50.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=50.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=50.0, gamma=1.0, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=50.0, gamma=1.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=50.0, gamma=1.0, kernel=poly; total time=   1.4s
# [CV 4/5] END .................C=50.0, gamma=1.0, kernel=poly; total time=   2.7s
# [CV 5/5] END .................C=50.0, gamma=1.0, kernel=poly; total time=   1.1s
# [CV 1/5] END ...............C=50.0, gamma=5.0, kernel=linear; total time=   0.2s
# [CV 2/5] END ...............C=50.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=50.0, gamma=5.0, kernel=linear; total time=   0.6s
# [CV 4/5] END ...............C=50.0, gamma=5.0, kernel=linear; total time=   2.2s
# [CV 5/5] END ...............C=50.0, gamma=5.0, kernel=linear; total time=   1.0s
# [CV 1/5] END ..................C=50.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=50.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=50.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=50.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=50.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=50.0, gamma=5.0, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=50.0, gamma=5.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=50.0, gamma=5.0, kernel=poly; total time=   2.2s
# [CV 4/5] END .................C=50.0, gamma=5.0, kernel=poly; total time=   3.5s
# [CV 5/5] END .................C=50.0, gamma=5.0, kernel=poly; total time=   1.9s
# [CV 1/5] END ..............C=50.0, gamma=10.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ..............C=50.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=50.0, gamma=10.0, kernel=linear; total time=   0.5s
# [CV 4/5] END ..............C=50.0, gamma=10.0, kernel=linear; total time=   2.0s
# [CV 5/5] END ..............C=50.0, gamma=10.0, kernel=linear; total time=   1.0s
# [CV 1/5] END .................C=50.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=50.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=50.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=50.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=50.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=50.0, gamma=10.0, kernel=poly; total time=   0.5s
# [CV 2/5] END ................C=50.0, gamma=10.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ................C=50.0, gamma=10.0, kernel=poly; total time=   2.3s
# [CV 4/5] END ................C=50.0, gamma=10.0, kernel=poly; total time=   3.6s
# [CV 5/5] END ................C=50.0, gamma=10.0, kernel=poly; total time=   1.9s
# [CV 1/5] END ..............C=10.0, gamma=0.01, kernel=linear; total time=   0.1s
# [CV 2/5] END ..............C=10.0, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=10.0, gamma=0.01, kernel=linear; total time=   0.4s
# [CV 4/5] END ..............C=10.0, gamma=0.01, kernel=linear; total time=   1.0s
# [CV 5/5] END ..............C=10.0, gamma=0.01, kernel=linear; total time=   0.2s
# [CV 1/5] END .................C=10.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=10.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=10.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=10.0, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=10.0, gamma=0.01, kernel=poly; total time=   0.4s
# [CV 2/5] END ................C=10.0, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 3/5] END ................C=10.0, gamma=0.01, kernel=poly; total time=   2.0s
# [CV 4/5] END ................C=10.0, gamma=0.01, kernel=poly; total time=   2.6s
# [CV 5/5] END ................C=10.0, gamma=0.01, kernel=poly; total time=   1.8s
# [CV 1/5] END ..............C=10.0, gamma=0.05, kernel=linear; total time=   0.1s
# [CV 2/5] END ..............C=10.0, gamma=0.05, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=10.0, gamma=0.05, kernel=linear; total time=   0.5s
# [CV 4/5] END ..............C=10.0, gamma=0.05, kernel=linear; total time=   1.1s
# [CV 5/5] END ..............C=10.0, gamma=0.05, kernel=linear; total time=   0.2s
# [CV 1/5] END .................C=10.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=10.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=10.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=10.0, gamma=0.05, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=10.0, gamma=0.05, kernel=poly; total time=   0.3s
# [CV 2/5] END ................C=10.0, gamma=0.05, kernel=poly; total time=   0.0s
# [CV 3/5] END ................C=10.0, gamma=0.05, kernel=poly; total time=   2.0s
# [CV 4/5] END ................C=10.0, gamma=0.05, kernel=poly; total time=   3.6s
# [CV 5/5] END ................C=10.0, gamma=0.05, kernel=poly; total time=   1.6s
# [CV 1/5] END ...............C=10.0, gamma=0.1, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=10.0, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=10.0, gamma=0.1, kernel=linear; total time=   0.4s
# [CV 4/5] END ...............C=10.0, gamma=0.1, kernel=linear; total time=   1.1s
# [CV 5/5] END ...............C=10.0, gamma=0.1, kernel=linear; total time=   0.3s
# [CV 1/5] END ..................C=10.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=10.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=10.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=10.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=10.0, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=10.0, gamma=0.1, kernel=poly; total time=   0.3s
# [CV 2/5] END .................C=10.0, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=0.1, kernel=poly; total time=   2.0s
# [CV 4/5] END .................C=10.0, gamma=0.1, kernel=poly; total time=   3.6s
# [CV 5/5] END .................C=10.0, gamma=0.1, kernel=poly; total time=   1.7s
# [CV 1/5] END ..............C=10.0, gamma=0.25, kernel=linear; total time=   0.1s
# [CV 2/5] END ..............C=10.0, gamma=0.25, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=10.0, gamma=0.25, kernel=linear; total time=   0.4s
# [CV 4/5] END ..............C=10.0, gamma=0.25, kernel=linear; total time=   1.1s
# [CV 5/5] END ..............C=10.0, gamma=0.25, kernel=linear; total time=   0.2s
# [CV 1/5] END .................C=10.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=10.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=10.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=10.0, gamma=0.25, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=10.0, gamma=0.25, kernel=poly; total time=   0.3s
# [CV 2/5] END ................C=10.0, gamma=0.25, kernel=poly; total time=   0.0s
# [CV 3/5] END ................C=10.0, gamma=0.25, kernel=poly; total time=   1.4s
# [CV 4/5] END ................C=10.0, gamma=0.25, kernel=poly; total time=   2.6s
# [CV 5/5] END ................C=10.0, gamma=0.25, kernel=poly; total time=   1.1s
# [CV 1/5] END ...............C=10.0, gamma=0.5, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=10.0, gamma=0.5, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=10.0, gamma=0.5, kernel=linear; total time=   0.4s
# [CV 4/5] END ...............C=10.0, gamma=0.5, kernel=linear; total time=   1.0s
# [CV 5/5] END ...............C=10.0, gamma=0.5, kernel=linear; total time=   0.2s
# [CV 1/5] END ..................C=10.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=10.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=10.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=10.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=10.0, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=10.0, gamma=0.5, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=10.0, gamma=0.5, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=0.5, kernel=poly; total time=   1.3s
# [CV 4/5] END .................C=10.0, gamma=0.5, kernel=poly; total time=   2.5s
# [CV 5/5] END .................C=10.0, gamma=0.5, kernel=poly; total time=   1.1s
# [CV 1/5] END ...............C=10.0, gamma=1.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=10.0, gamma=1.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=10.0, gamma=1.0, kernel=linear; total time=   0.4s
# [CV 4/5] END ...............C=10.0, gamma=1.0, kernel=linear; total time=   1.1s
# [CV 5/5] END ...............C=10.0, gamma=1.0, kernel=linear; total time=   0.2s
# [CV 1/5] END ..................C=10.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=10.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=10.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=10.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=10.0, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=10.0, gamma=1.0, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=10.0, gamma=1.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=1.0, kernel=poly; total time=   1.3s
# [CV 4/5] END .................C=10.0, gamma=1.0, kernel=poly; total time=   2.8s
# [CV 5/5] END .................C=10.0, gamma=1.0, kernel=poly; total time=   1.1s
# [CV 1/5] END ...............C=10.0, gamma=5.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ...............C=10.0, gamma=5.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=10.0, gamma=5.0, kernel=linear; total time=   0.4s
# [CV 4/5] END ...............C=10.0, gamma=5.0, kernel=linear; total time=   1.1s
# [CV 5/5] END ...............C=10.0, gamma=5.0, kernel=linear; total time=   0.2s
# [CV 1/5] END ..................C=10.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=10.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=10.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=10.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=10.0, gamma=5.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=10.0, gamma=5.0, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=10.0, gamma=5.0, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=5.0, kernel=poly; total time=   2.1s
# [CV 4/5] END .................C=10.0, gamma=5.0, kernel=poly; total time=   3.6s
# [CV 5/5] END .................C=10.0, gamma=5.0, kernel=poly; total time=   1.8s
# [CV 1/5] END ..............C=10.0, gamma=10.0, kernel=linear; total time=   0.1s
# [CV 2/5] END ..............C=10.0, gamma=10.0, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=10.0, gamma=10.0, kernel=linear; total time=   0.4s
# [CV 4/5] END ..............C=10.0, gamma=10.0, kernel=linear; total time=   1.0s
# [CV 5/5] END ..............C=10.0, gamma=10.0, kernel=linear; total time=   0.2s
# [CV 1/5] END .................C=10.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=10.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=10.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=10.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=10.0, gamma=10.0, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=10.0, gamma=10.0, kernel=poly; total time=   0.4s
# [CV 2/5] END ................C=10.0, gamma=10.0, kernel=poly; total time=   0.0s
# [CV 3/5] END ................C=10.0, gamma=10.0, kernel=poly; total time=   2.1s
# [CV 4/5] END ................C=10.0, gamma=10.0, kernel=poly; total time=   3.7s
# [CV 5/5] END ................C=10.0, gamma=10.0, kernel=poly; total time=   1.9s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 0.5, 1.0, 2.0, 5.0, 10.0, 25.0, 50.0, 10.0],
#                          'gamma': [0.01, 0.05, 0.1, 0.25, 0.5, 1.0, 5.0, 10.0],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              verbose=3)

# %%
clf.best_score_
# Out:
# 0.9130434782608695

# %%
clf.best_params_
# Out:
# {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}

# %%
pd.DataFrame(clf.cv_results_).head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.015803      0.006225         0.002789        0.001156     0.1
# 1       0.002198      0.001165         0.001412        0.000795     0.1
# 2       1.119293      0.798338         0.000821        0.001007     0.1
# 3       0.012363      0.004273         0.002048        0.003145     0.1
# 4       0.005252      0.004348         0.000421        0.000842     0.1
#
#   param_gamma param_kernel                                         params  \
# 0        0.01       linear  {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# 1        0.01          rbf     {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 2        0.01         poly    {'C': 0.1, 'gamma': 0.01, 'kernel': 'poly'}
# 3        0.05       linear  {'C': 0.1, 'gamma': 0.05, 'kernel': 'linear'}
# 4        0.05          rbf     {'C': 0.1, 'gamma': 0.05, 'kernel': 'rbf'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.913043           0.826087           0.913043           0.913043
# 1           0.608696           0.608696           0.608696           0.608696
# 2           0.782609           0.782609           1.000000           0.913043
# 3           0.913043           0.826087           0.913043           0.913043
# 4           0.608696           0.608696           0.608696           0.608696
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           1.000000         0.913043        0.054996                1
# 1           0.636364         0.614229        0.011067              145
# 2           0.954545         0.886561        0.089223               73
# 3           1.000000         0.913043        0.054996                1
# 4           0.636364         0.614229        0.011067              145

# %% [markdown]
# # Best parameters are found

# %%
model2 = SVC(**clf.best_params_)

model2.fit(X_train, y_train)
y_predict = model2.predict(X_test)

print('test: ', accuracy_score(y_test, y_predict))
# Out:
# test:  0.9385964912280702

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95        70
#            1       0.88      0.98      0.92        44
#
#     accuracy                           0.94       114
#    macro avg       0.93      0.95      0.94       114
# weighted avg       0.94      0.94      0.94       114

# %% [markdown]
# # K Fold Cross Validation

# %% [markdown]
# - K / n / folds is the number of folds we need
# - for each fold accuracy result is calculated
# - then an arithmetic mean of those scores will be the accuracy score of the model
# - hence reliance on random_state is eradicated
