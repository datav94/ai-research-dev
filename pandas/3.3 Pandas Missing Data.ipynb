# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mtcars_missing_data.csv')
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08    NaN  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     30 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    30 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    30 non-null     float64
#  6   wt      29 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      2
# cyl      0
# disp     2
# hp       0
# drat     2
# wt       3
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df.fillna(100)
# Out:
#                   model    mpg  cyl   disp   hp    drat       wt   qsec  vs  \
# 0             Mazda RX4   21.0    6  160.0  110    3.90    2.620  16.46   0
# 1         Mazda RX4 Wag   21.0    6  160.0  110    3.90    2.875  17.02   0
# 2            Datsun 710   22.8    4  108.0   93    3.85    2.320  18.61   1
# 3        Hornet 4 Drive   21.4    6  258.0  110    3.08  100.000  19.44   1
# 4     Hornet Sportabout   18.7    8  360.0  175    3.15    3.440  17.02   0
# 5               Valiant   18.1    6  225.0  105    2.76    3.460  20.22   1
# 6            Duster 360   14.3    8  360.0  245  100.00    3.570  15.84   0
# 7             Merc 240D   24.4    4  146.7   62    3.69    3.190  20.00   1
# 8              Merc 230  100.0    4  140.8   95    3.92    3.150  22.90   1
# 9              Merc 280   19.2    6  167.6  123    3.92    3.440  18.30   1
# 10            Merc 280C   17.8    6  167.6  123    3.92    3.440  18.90   1
# ...

# %% [markdown]
# # __FORWARD AND BACKWARD FILL__

# %%
df.sort_values('mpg').fillna(method='ffill') # works on DataFrame and Pandas Series
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 6            Duster 360  14.3    8  360.0  245  3.73  3.570  15.84   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %%
df.fillna(method='bfill')
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.440  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.69  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  19.2    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# # Fill with mean

# %%
df.fillna(df.mean())
# Out:
# <ipython-input-32-a2478f315f9e>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#                   model        mpg  cyl    disp   hp      drat        wt  \
# 0             Mazda RX4  21.000000    6  160.00  110  3.900000  2.620000
# 1         Mazda RX4 Wag  21.000000    6  160.00  110  3.900000  2.875000
# 2            Datsun 710  22.800000    4  108.00   93  3.850000  2.320000
# 3        Hornet 4 Drive  21.400000    6  258.00  110  3.080000  3.258414
# 4     Hornet Sportabout  18.700000    8  360.00  175  3.150000  3.440000
# 5               Valiant  18.100000    6  225.00  105  2.760000  3.460000
# 6            Duster 360  14.300000    8  360.00  245  3.588667  3.570000
# 7             Merc 240D  24.400000    4  146.70   62  3.690000  3.190000
# ...

# %%
df.dropna().shape
# Out:
# (25, 12)

# %%
# if you wanna make that change permanent just set inplace kwargs to True inplace=True

# %%
df_new =df

# %%
df_new
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08    NaN  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245   NaN  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230   NaN    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df_new.drop(['model','disp','drat'], axis=1, inplace=True) 
# if axis is not set to column i.e. 1 it will throw an error
#this is the case coz axis is set to 0 i.e. rows by default and we are trying to drop columns

# %%
df_new.interpolate()
# Out:
#      mpg  cyl   hp     wt   qsec  vs  am  gear  carb
# 0   21.0    6  110  2.620  16.46   0   1     4     4
# 1   21.0    6  110  2.875  17.02   0   1     4     4
# 2   22.8    4   93  2.320  18.61   1   1     4     1
# 3   21.4    6  110  2.880  19.44   1   0     3     1
# 4   18.7    8  175  3.440  17.02   0   0     3     2
# 5   18.1    6  105  3.460  20.22   1   0     3     1
# 6   14.3    8  245  3.570  15.84   0   0     3     4
# 7   24.4    4   62  3.190  20.00   1   0     4     2
# 8   21.8    4   95  3.150  22.90   1   0     4     2
# 9   19.2    6  123  3.440  18.30   1   0     4     4
# 10  17.8    6  123  3.440  18.90   1   0     4     4
# 11  16.4    8  180  4.070  17.40   0   0     3     3
# 12  17.3    8  180  3.925  17.60   0   0     3     3
# 13  15.2    8  180  3.780  18.00   0   0     3     3
# 14  10.4    8  205  5.250  17.98   0   0     3     4
# 15  10.4    8  215  5.424  17.82   0   0     3     4
# 16  14.7    8  230  5.345  17.42   0   0     3     4
# ...
